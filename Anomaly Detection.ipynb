# %%
import pandas as pd
import numpy as np

from sklearn.metrics import (
    f1_score, precision_score, recall_score,
    roc_auc_score, confusion_matrix
)
from sklearn.preprocessing import StandardScaler
from sklearn.pipeline import Pipeline
from sklearn.impute import SimpleImputer

from sklearn.svm import OneClassSVM
from sklearn.ensemble import IsolationForest

import optuna

# %%
df = pd.read_parquet("df_preprocessed.parquet")

train_cycles = ["A1", "B1", "B3"]
val_cycle    = "A2"
test_cycle   = "B2"

df_train = df[df["cycle_id"].isin(train_cycles)].copy()
df_val   = df[df["cycle_id"] == val_cycle].copy()
df_test  = df[df["cycle_id"] == test_cycle].copy()

# Full feature set
feature_cols_all = [
    c for c in df_train.columns
    if c not in ["pump_id", "cycle_id", "end_time", "label"]
]

X_train_full = df_train[feature_cols_all]
X_val_full   = df_val[feature_cols_all]
X_test_full  = df_test[feature_cols_all]

y_train_full = df_train["label"]
y_val_full   = df_val["label"]
y_test_full  = df_test["label"]

# %%
# One class svm prep


# Select only no-failure windows for training
df_train_ano = df_train[df_train["label"] == 0]

X_train_ano = df_train_ano[feature_cols_all]
X_val_ano   = df_val[feature_cols_all]
X_test_ano  = df_test[feature_cols_all]

y_val_ano = df_val["label"]
y_test_ano = df_test["label"]

# Median imputation (torque )
imputer_ano = SimpleImputer(strategy="median")

X_train_ano_imp = pd.DataFrame(imputer_ano.fit_transform(X_train_ano), columns=feature_cols_all)
X_val_ano_imp   = pd.DataFrame(imputer_ano.transform(X_val_ano), columns=feature_cols_all)
X_test_ano_imp  = pd.DataFrame(imputer_ano.transform(X_test_ano), columns=feature_cols_all)



# one class svm hyperparameter tuning

def ocsvm_objective(trial):

    params = {
        "kernel": trial.suggest_categorical("kernel", ["rbf", "poly"]),
        "nu": trial.suggest_float("nu", 0.01, 0.20),
        "gamma": trial.suggest_categorical("gamma", ["scale", "auto"]),
    }

    pipe = Pipeline([
        ("scale", StandardScaler()),
        ("ocsvm", OneClassSVM(**params))
    ])

    pipe.fit(X_train_ano_imp)

    scores = pipe.decision_function(X_val_ano_imp)
    thresholds = np.linspace(np.percentile(scores, 1),
                             np.percentile(scores, 40), 50)

    best_f1 = 0
    for t in thresholds:
        preds = (scores < t).astype(int)
        best_f1 = max(best_f1, f1_score(y_val_ano, preds, zero_division=0))

    return best_f1

# %%
# one class svm running optuna
study_ocsvm = optuna.create_study(direction="maximize")
study_ocsvm.optimize(ocsvm_objective, n_trials=40)

best_params_ocsvm = study_ocsvm.best_params
best_params_ocsvm
# Out:
# [I 2025-12-01 13:17:30,570] A new study created in memory with name: no-name-2c108c68-f7fd-42b5-b67d-f854c4af04da
# [I 2025-12-01 13:17:31,079] Trial 0 finished with value: 0.11659192825112108 and parameters: {'kernel': 'rbf', 'nu': 0.07538782260486931, 'gamma': 'auto'}. Best is trial 0 with value: 0.11659192825112108.
# [I 2025-12-01 13:17:31,645] Trial 1 finished with value: 0.11325611325611326 and parameters: {'kernel': 'rbf', 'nu': 0.09257407890107919, 'gamma': 'auto'}. Best is trial 0 with value: 0.11659192825112108.
# [I 2025-12-01 13:17:31,790] Trial 2 finished with value: 0.12263535551206783 and parameters: {'kernel': 'rbf', 'nu': 0.013567368269417363, 'gamma': 'scale'}. Best is trial 2 with value: 0.12263535551206783.
# [I 2025-12-01 13:17:32,257] Trial 3 finished with value: 0.11702127659574468 and parameters: {'kernel': 'rbf', 'nu': 0.07356696755933731, 'gamma': 'auto'}. Best is trial 2 with value: 0.12263535551206783.
# [I 2025-12-01 13:17:32,878] Trial 4 finished with value: 0.11568409343715239 and parameters: {'kernel': 'poly', 'nu': 0.12936212618500745, 'gamma': 'auto'}. Best is trial 2 with value: 0.12263535551206783.
# [I 2025-12-01 13:17:33,249] Trial 5 finished with value: 0.11012235817575083 and parameters: {'kernel': 'poly', 'nu': 0.05261820570882679, 'gamma': 'scale'}. Best is trial 2 with value: 0.12263535551206783.
# [I 2025-12-01 13:17:34,075] Trial 6 finished with value: 0.1167964404894327 and parameters: {'kernel': 'poly', 'nu': 0.15012199091657988, 'gamma': 'scale'}. Best is trial 2 with value: 0.12263535551206783.
# [I 2025-12-01 13:17:34,578] Trial 7 finished with value: 0.11659192825112108 and parameters: {'kernel': 'rbf', 'nu': 0.07763034808852987, 'gamma': 'auto'}. Best is trial 2 with value: 0.12263535551206783.
# [I 2025-12-01 13:17:35,676] Trial 8 finished with value: 0.10011123470522804 and parameters: {'kernel': 'rbf', 'nu': 0.18418255644656506, 'gamma': 'scale'}. Best is trial 2 with value: 0.12263535551206783.
# [I 2025-12-01 13:17:36,559] Trial 9 finished with value: 0.12347052280311457 and parameters: {'kernel': 'poly', 'nu': 0.17764351017048793, 'gamma': 'auto'}. Best is trial 9 with value: 0.12347052280311457.
# [I 2025-12-01 13:17:37,450] Trial 10 finished with value: 0.12680756395995552 and parameters: {'kernel': 'poly', 'nu': 0.19006504561766016, 'gamma': 'auto'}. Best is trial 10 with value: 0.12680756395995552.
# [I 2025-12-01 13:17:38,331] Trial 11 finished with value: 0.12680756395995552 and parameters: {'kernel': 'poly', 'nu': 0.19142889645416553, 'gamma': 'auto'}. Best is trial 10 with value: 0.12680756395995552.
# [I 2025-12-01 13:17:39,320] Trial 12 finished with value: 0.12791991101223582 and parameters: {'kernel': 'poly', 'nu': 0.1968809599578709, 'gamma': 'auto'}. Best is trial 12 with value: 0.12791991101223582.
# [I 2025-12-01 13:17:40,100] Trial 13 finished with value: 0.1167964404894327 and parameters: {'kernel': 'poly', 'nu': 0.14561121992476692, 'gamma': 'auto'}. Best is trial 12 with value: 0.12791991101223582.
# [I 2025-12-01 13:17:40,984] Trial 14 finished with value: 0.12791991101223582 and parameters: {'kernel': 'poly', 'nu': 0.19771288132375567, 'gamma': 'auto'}. Best is trial 12 with value: 0.12791991101223582.
# [I 2025-12-01 13:17:41,767] Trial 15 finished with value: 0.1167964404894327 and parameters: {'kernel': 'poly', 'nu': 0.1571182805439172, 'gamma': 'auto'}. Best is trial 12 with value: 0.12791991101223582.
# [I 2025-12-01 13:17:42,354] Trial 16 finished with value: 0.11457174638487208 and parameters: {'kernel': 'poly', 'nu': 0.12076684243991262, 'gamma': 'auto'}. Best is trial 12 with value: 0.12791991101223582.
# [I 2025-12-01 13:17:43,153] Trial 17 finished with value: 0.11790878754171301 and parameters: {'kernel': 'poly', 'nu': 0.16789283848992037, 'gamma': 'auto'}. Best is trial 12 with value: 0.12791991101223582.
# [I 2025-12-01 13:17:43,764] Trial 18 finished with value: 0.11568409343715239 and parameters: {'kernel': 'poly', 'nu': 0.1271989611424858, 'gamma': 'scale'}. Best is trial 12 with value: 0.12791991101223582.
# [I 2025-12-01 13:17:44,654] Trial 19 finished with value: 0.12791991101223582 and parameters: {'kernel': 'poly', 'nu': 0.19515002636953144, 'gamma': 'auto'}. Best is trial 12 with value: 0.12791991101223582.
# [I 2025-12-01 13:17:45,446] Trial 20 finished with value: 0.11790878754171301 and parameters: {'kernel': 'poly', 'nu': 0.1656435032825572, 'gamma': 'auto'}. Best is trial 12 with value: 0.12791991101223582.
# [I 2025-12-01 13:17:46,354] Trial 21 finished with value: 0.12791991101223582 and parameters: {'kernel': 'poly', 'nu': 0.1986796606875445, 'gamma': 'auto'}. Best is trial 12 with value: 0.12791991101223582.
# [I 2025-12-01 13:17:47,388] Trial 22 finished with value: 0.12791991101223582 and parameters: {'kernel': 'poly', 'nu': 0.1994902947577326, 'gamma': 'auto'}. Best is trial 12 with value: 0.12791991101223582.
# [I 2025-12-01 13:17:48,223] Trial 23 finished with value: 0.12347052280311457 and parameters: {'kernel': 'poly', 'nu': 0.17798286306023434, 'gamma': 'auto'}. Best is trial 12 with value: 0.12791991101223582.
# [I 2025-12-01 13:17:48,955] Trial 24 finished with value: 0.1167964404894327 and parameters: {'kernel': 'poly', 'nu': 0.14147391041664253, 'gamma': 'auto'}. Best is trial 12 with value: 0.12791991101223582.
# [I 2025-12-01 13:17:49,745] Trial 25 finished with value: 0.12124582869855395 and parameters: {'kernel': 'poly', 'nu': 0.16986051374072134, 'gamma': 'auto'}. Best is trial 12 with value: 0.12791991101223582.
# [I 2025-12-01 13:17:50,524] Trial 26 finished with value: 0.1167964404894327 and parameters: {'kernel': 'poly', 'nu': 0.15917023109767395, 'gamma': 'scale'}. Best is trial 12 with value: 0.12791991101223582.
# [I 2025-12-01 13:17:51,080] Trial 27 finished with value: 0.11457174638487208 and parameters: {'kernel': 'poly', 'nu': 0.10602219279568673, 'gamma': 'auto'}. Best is trial 12 with value: 0.12791991101223582.
# [I 2025-12-01 13:17:51,946] Trial 28 finished with value: 0.12680756395995552 and parameters: {'kernel': 'poly', 'nu': 0.18217236246226848, 'gamma': 'auto'}. Best is trial 12 with value: 0.12791991101223582.
# [I 2025-12-01 13:17:52,125] Trial 29 finished with value: 0.12279555845852384 and parameters: {'kernel': 'rbf', 'nu': 0.019535911754280127, 'gamma': 'auto'}. Best is trial 12 with value: 0.12791991101223582.
# [I 2025-12-01 13:17:53,056] Trial 30 finished with value: 0.12791991101223582 and parameters: {'kernel': 'poly', 'nu': 0.1994020890800263, 'gamma': 'auto'}. Best is trial 12 with value: 0.12791991101223582.
# [I 2025-12-01 13:17:53,985] Trial 31 finished with value: 0.12791991101223582 and parameters: {'kernel': 'poly', 'nu': 0.19975021612009397, 'gamma': 'auto'}. Best is trial 12 with value: 0.12791991101223582.
# [I 2025-12-01 13:17:54,855] Trial 32 finished with value: 0.12347052280311457 and parameters: {'kernel': 'poly', 'nu': 0.17547874209311562, 'gamma': 'auto'}. Best is trial 12 with value: 0.12791991101223582.
# [I 2025-12-01 13:17:55,745] Trial 33 finished with value: 0.12680756395995552 and parameters: {'kernel': 'poly', 'nu': 0.18809444204845477, 'gamma': 'auto'}. Best is trial 12 with value: 0.12791991101223582.
# [I 2025-12-01 13:17:56,855] Trial 34 finished with value: 0.10011123470522804 and parameters: {'kernel': 'rbf', 'nu': 0.18981268802721107, 'gamma': 'auto'}. Best is trial 12 with value: 0.12791991101223582.
# [I 2025-12-01 13:17:57,641] Trial 35 finished with value: 0.11790878754171301 and parameters: {'kernel': 'poly', 'nu': 0.16325069714787377, 'gamma': 'auto'}. Best is trial 12 with value: 0.12791991101223582.
# [I 2025-12-01 13:17:58,799] Trial 36 finished with value: 0.09899888765294772 and parameters: {'kernel': 'rbf', 'nu': 0.19921487557327647, 'gamma': 'scale'}. Best is trial 12 with value: 0.12791991101223582.
# [I 2025-12-01 13:17:59,594] Trial 37 finished with value: 0.1167964404894327 and parameters: {'kernel': 'poly', 'nu': 0.15362265373950784, 'gamma': 'auto'}. Best is trial 12 with value: 0.12791991101223582.
# [I 2025-12-01 13:17:59,946] Trial 38 finished with value: 0.10901001112347053 and parameters: {'kernel': 'poly', 'nu': 0.04952461785351417, 'gamma': 'auto'}. Best is trial 12 with value: 0.12791991101223582.
# [I 2025-12-01 13:18:00,989] Trial 39 finished with value: 0.10011123470522804 and parameters: {'kernel': 'rbf', 'nu': 0.17491729745056592, 'gamma': 'scale'}. Best is trial 12 with value: 0.12791991101223582.
# {'kernel': 'poly', 'nu': 0.1968809599578709, 'gamma': 'auto'}

# %%
# one class fit best params
ocsvm_final = Pipeline([
    ("scale", StandardScaler()),
    ("ocsvm", OneClassSVM(**best_params_ocsvm))
])
ocsvm_final.fit(X_train_ano_imp)

# ---- Threshold search on validation 
scores_val = ocsvm_final.decision_function(X_val_ano_imp)
thresholds = np.linspace(np.percentile(scores_val, 1),
                         np.percentile(scores_val, 40), 50)

best_thresh = None
best_f1_val = -1

for t in thresholds:
    preds = (scores_val < t).astype(int)
    f1 = f1_score(y_val_ano, preds, zero_division=0)
    if f1 > best_f1_val:
        best_thresh = t
        best_f1_val = f1

print("Best OC-SVM threshold:", best_thresh)
print("Best OC-SVM validation F1:", best_f1_val)
# Out:
# Best OC-SVM threshold: -3.329323217128773
# Best OC-SVM validation F1: 0.12791991101223582

# %%
#evaluate on val and test

def eval_anomaly(model, X, y, threshold):
    scores = model.decision_function(X)
    preds = (scores < threshold).astype(int)

    return {
        "Precision": precision_score(y, preds, zero_division=0),
        "Recall": recall_score(y, preds, zero_division=0),
        "F1": f1_score(y, preds, zero_division=0),
        "ROC-AUC": roc_auc_score(y, scores)
    }


oc_val_metrics = eval_anomaly(ocsvm_final, X_val_ano_imp, y_val_ano, best_thresh)
oc_test_metrics = eval_anomaly(ocsvm_final, X_test_ano_imp, y_test_ano, best_thresh)

print("OC-SVM Validation:", oc_val_metrics)
print("OC-SVM Test:", oc_test_metrics)
# Out:
# OC-SVM Validation: {'Precision': 0.0705521472392638, 'Recall': 0.6845238095238095, 'F1': 0.12791991101223582, 'ROC-AUC': np.float64(0.3427493054540137)}
# OC-SVM Test: {'Precision': 0.0, 'Recall': 0.0, 'F1': 0.0, 'ROC-AUC': np.float64(0.744450424969042)}

# %%
# Isolation forest prep

# -only no failure windows:
healthy_train_if = df_train[df_train["label"] == 0]

X_train_if_raw = healthy_train_if[feature_cols_all]
X_val_if_raw   = X_val_full
X_test_if_raw  = X_test_full

y_val_if  = y_val_full
y_test_if = y_test_full

# Impute torque
imp_if = SimpleImputer(strategy="median")
X_train_if = imp_if.fit_transform(X_train_if_raw)
X_val_if   = imp_if.transform(X_val_if_raw)
X_test_if  = imp_if.transform(X_test_if_raw)


# objective:
def iforest_objective(trial):

    params = {
        "n_estimators": trial.suggest_int("n_estimators", 100, 400),
        "max_samples": trial.suggest_float("max_samples", 0.6, 1.0),
        "contamination": trial.suggest_float("contamination", 0.01, 0.10),
        "random_state": 42
    }

    model = IsolationForest(**params)
    model.fit(X_train_if)

    scores = model.decision_function(X_val_if)
    ths = np.linspace(scores.min(), scores.max(), 200)

    best_f1 = 0
    for th in ths:
        preds = (scores < th).astype(int)
        best_f1 = max(best_f1, f1_score(y_val_if, preds, zero_division=0))

    return best_f1

# %%
# isolation forest running optuna:
study_if = optuna.create_study(direction="maximize")
study_if.optimize(iforest_objective, n_trials=40)

best_params_if = study_if.best_params
best_params_if
# Out:
# [I 2025-12-01 13:19:59,722] A new study created in memory with name: no-name-6d2f897a-753c-4099-95fb-65174a4de744
# [I 2025-12-01 13:20:00,403] Trial 0 finished with value: 0.07871788828658968 and parameters: {'n_estimators': 219, 'max_samples': 0.7955949716730366, 'contamination': 0.021612528983026777}. Best is trial 0 with value: 0.07871788828658968.
# [I 2025-12-01 13:20:01,217] Trial 1 finished with value: 0.07871788828658968 and parameters: {'n_estimators': 252, 'max_samples': 0.9804308637364729, 'contamination': 0.08234111558975715}. Best is trial 0 with value: 0.07871788828658968.
# [I 2025-12-01 13:20:01,788] Trial 2 finished with value: 0.07871788828658968 and parameters: {'n_estimators': 177, 'max_samples': 0.9126258169099815, 'contamination': 0.09006421902210708}. Best is trial 0 with value: 0.07871788828658968.
# [I 2025-12-01 13:20:02,856] Trial 3 finished with value: 0.07965860597439545 and parameters: {'n_estimators': 397, 'max_samples': 0.8779410715949818, 'contamination': 0.0502726431878716}. Best is trial 3 with value: 0.07965860597439545.
# [I 2025-12-01 13:20:03,464] Trial 4 finished with value: 0.07980997624703087 and parameters: {'n_estimators': 214, 'max_samples': 0.6697930129063405, 'contamination': 0.08694545041193952}. Best is trial 4 with value: 0.07980997624703087.
# [I 2025-12-01 13:20:03,966] Trial 5 finished with value: 0.07963972505333017 and parameters: {'n_estimators': 160, 'max_samples': 0.7435711609821131, 'contamination': 0.08825101592498649}. Best is trial 4 with value: 0.07980997624703087.
# [I 2025-12-01 13:20:04,510] Trial 6 finished with value: 0.07871788828658968 and parameters: {'n_estimators': 160, 'max_samples': 0.9725667412498253, 'contamination': 0.049502866463661796}. Best is trial 4 with value: 0.07980997624703087.
# [I 2025-12-01 13:20:05,033] Trial 7 finished with value: 0.07939508506616257 and parameters: {'n_estimators': 146, 'max_samples': 0.9489195589284021, 'contamination': 0.03487237588517654}. Best is trial 4 with value: 0.07980997624703087.
# [I 2025-12-01 13:20:05,512] Trial 8 finished with value: 0.07918925288710818 and parameters: {'n_estimators': 131, 'max_samples': 0.8975878828106841, 'contamination': 0.05644609210891873}. Best is trial 4 with value: 0.07980997624703087.
# [I 2025-12-01 13:20:06,391] Trial 9 finished with value: 0.07958313595452392 and parameters: {'n_estimators': 354, 'max_samples': 0.6736968234085366, 'contamination': 0.03145842843323404}. Best is trial 4 with value: 0.07980997624703087.
# [I 2025-12-01 13:20:07,092] Trial 10 finished with value: 0.0797153024911032 and parameters: {'n_estimators': 267, 'max_samples': 0.6050427205001767, 'contamination': 0.0715864424447846}. Best is trial 4 with value: 0.07980997624703087.
# [I 2025-12-01 13:20:07,852] Trial 11 finished with value: 0.07980997624703087 and parameters: {'n_estimators': 289, 'max_samples': 0.634195778777805, 'contamination': 0.07111643600910936}. Best is trial 4 with value: 0.07980997624703087.
# [I 2025-12-01 13:20:08,613] Trial 12 finished with value: 0.08001905215527506 and parameters: {'n_estimators': 309, 'max_samples': 0.6088316135190421, 'contamination': 0.09925002821801059}. Best is trial 12 with value: 0.08001905215527506.
# [I 2025-12-01 13:20:09,438] Trial 13 finished with value: 0.07939508506616257 and parameters: {'n_estimators': 318, 'max_samples': 0.7167029433642332, 'contamination': 0.098448643642806}. Best is trial 12 with value: 0.08001905215527506.
# [I 2025-12-01 13:20:10,078] Trial 14 finished with value: 0.07973421926910298 and parameters: {'n_estimators': 225, 'max_samples': 0.6703529014421656, 'contamination': 0.09956806279173296}. Best is trial 12 with value: 0.08001905215527506.
# [I 2025-12-01 13:20:10,994] Trial 15 finished with value: 0.07960199004975124 and parameters: {'n_estimators': 323, 'max_samples': 0.7601690215574135, 'contamination': 0.07115884565275868}. Best is trial 12 with value: 0.08001905215527506.
# [I 2025-12-01 13:20:11,604] Trial 16 finished with value: 0.07965657047460052 and parameters: {'n_estimators': 206, 'max_samples': 0.6865761242510323, 'contamination': 0.08071406471108701}. Best is trial 12 with value: 0.08001905215527506.
# [I 2025-12-01 13:20:12,018] Trial 17 finished with value: 0.0794889992902768 and parameters: {'n_estimators': 109, 'max_samples': 0.6049444726102261, 'contamination': 0.05896621398288697}. Best is trial 12 with value: 0.08001905215527506.
# [I 2025-12-01 13:20:12,812] Trial 18 finished with value: 0.07924528301886792 and parameters: {'n_estimators': 278, 'max_samples': 0.8065324724419446, 'contamination': 0.08993565067678565}. Best is trial 12 with value: 0.08001905215527506.
# [I 2025-12-01 13:20:13,736] Trial 19 finished with value: 0.08207132388861749 and parameters: {'n_estimators': 372, 'max_samples': 0.6382693171226503, 'contamination': 0.07840226280121461}. Best is trial 19 with value: 0.08207132388861749.
# [I 2025-12-01 13:20:14,776] Trial 20 finished with value: 0.07986688851913477 and parameters: {'n_estimators': 385, 'max_samples': 0.8247431972976765, 'contamination': 0.07658920128303387}. Best is trial 19 with value: 0.08207132388861749.
# [I 2025-12-01 13:20:15,894] Trial 21 finished with value: 0.07932011331444759 and parameters: {'n_estimators': 396, 'max_samples': 0.8398279788662137, 'contamination': 0.06384097212492469}. Best is trial 19 with value: 0.08207132388861749.
# [I 2025-12-01 13:20:16,817] Trial 22 finished with value: 0.07994289793004997 and parameters: {'n_estimators': 363, 'max_samples': 0.6371031677064384, 'contamination': 0.07728684707141283}. Best is trial 19 with value: 0.08207132388861749.
# [I 2025-12-01 13:20:17,695] Trial 23 finished with value: 0.07871788828658968 and parameters: {'n_estimators': 354, 'max_samples': 0.6258097403223275, 'contamination': 0.09431229850584516}. Best is trial 19 with value: 0.08207132388861749.
# [I 2025-12-01 13:20:18,543] Trial 24 finished with value: 0.07958313595452392 and parameters: {'n_estimators': 345, 'max_samples': 0.6422557134697222, 'contamination': 0.06376492420908862}. Best is trial 19 with value: 0.08207132388861749.
# [I 2025-12-01 13:20:19,344] Trial 25 finished with value: 0.07871788828658968 and parameters: {'n_estimators': 308, 'max_samples': 0.7075463771443434, 'contamination': 0.07738643088987139}. Best is trial 19 with value: 0.08207132388861749.
# [I 2025-12-01 13:20:20,291] Trial 26 finished with value: 0.07918925288710818 and parameters: {'n_estimators': 370, 'max_samples': 0.6461758397191828, 'contamination': 0.04277444552101528}. Best is trial 19 with value: 0.08207132388861749.
# [I 2025-12-01 13:20:21,251] Trial 27 finished with value: 0.07871788828658968 and parameters: {'n_estimators': 332, 'max_samples': 0.7466266177590453, 'contamination': 0.0834089211102279}. Best is trial 19 with value: 0.08207132388861749.
# [I 2025-12-01 13:20:22,056] Trial 28 finished with value: 0.07918925288710818 and parameters: {'n_estimators': 294, 'max_samples': 0.7134522100189282, 'contamination': 0.012572998979534435}. Best is trial 19 with value: 0.08207132388861749.
# [I 2025-12-01 13:20:22,923] Trial 29 finished with value: 0.07969639468690702 and parameters: {'n_estimators': 363, 'max_samples': 0.6022766265814172, 'contamination': 0.06449669223442012}. Best is trial 19 with value: 0.08207132388861749.
# [I 2025-12-01 13:20:23,873] Trial 30 finished with value: 0.07945140695199811 and parameters: {'n_estimators': 377, 'max_samples': 0.6556257064676131, 'contamination': 0.09497880475295645}. Best is trial 19 with value: 0.08207132388861749.
# [I 2025-12-01 13:20:24,874] Trial 31 finished with value: 0.07930139249468963 and parameters: {'n_estimators': 385, 'max_samples': 0.7998848923663978, 'contamination': 0.07662712742133468}. Best is trial 19 with value: 0.08207132388861749.
# [I 2025-12-01 13:20:25,770] Trial 32 finished with value: 0.07871788828658968 and parameters: {'n_estimators': 339, 'max_samples': 0.8466990813344667, 'contamination': 0.07559478373509355}. Best is trial 19 with value: 0.08207132388861749.
# [I 2025-12-01 13:20:26,743] Trial 33 finished with value: 0.07986688851913477 and parameters: {'n_estimators': 377, 'max_samples': 0.7737434926939878, 'contamination': 0.08517931032947493}. Best is trial 19 with value: 0.08207132388861749.
# [I 2025-12-01 13:20:27,583] Trial 34 finished with value: 0.07973421926910298 and parameters: {'n_estimators': 313, 'max_samples': 0.8363040573635353, 'contamination': 0.06847587297863879}. Best is trial 19 with value: 0.08207132388861749.
# [I 2025-12-01 13:20:28,610] Trial 35 finished with value: 0.08024838786720802 and parameters: {'n_estimators': 392, 'max_samples': 0.870401483183999, 'contamination': 0.07918679705129952}. Best is trial 19 with value: 0.08207132388861749.
# [I 2025-12-01 13:20:29,650] Trial 36 finished with value: 0.07980997624703087 and parameters: {'n_estimators': 397, 'max_samples': 0.8713183657204133, 'contamination': 0.09388149297006165}. Best is trial 19 with value: 0.08207132388861749.
# [I 2025-12-01 13:20:30,556] Trial 37 finished with value: 0.07992388201712655 and parameters: {'n_estimators': 361, 'max_samples': 0.6908822178964412, 'contamination': 0.050617477259696265}. Best is trial 19 with value: 0.08207132388861749.
# [I 2025-12-01 13:20:31,470] Trial 38 finished with value: 0.07871788828658968 and parameters: {'n_estimators': 338, 'max_samples': 0.9124089074495384, 'contamination': 0.08419145718848937}. Best is trial 19 with value: 0.08207132388861749.
# [I 2025-12-01 13:20:32,146] Trial 39 finished with value: 0.08226600985221674 and parameters: {'n_estimators': 243, 'max_samples': 0.6249081071367667, 'contamination': 0.08957483860572622}. Best is trial 39 with value: 0.08226600985221674.
# {'n_estimators': 243,
#  'max_samples': 0.6249081071367667,
#  'contamination': 0.08957483860572622}

# %%
# Isolation forest fit model
if_best = IsolationForest(**best_params_if, random_state=42)
if_best.fit(X_train_if)

# Scores
val_scores_if = if_best.decision_function(X_val_if)
test_scores_if = if_best.decision_function(X_test_if)

# Threshold search
ths = np.linspace(val_scores_if.min(), val_scores_if.max(), 300)
best_f1 = 0
best_th = None

for th in ths:
    preds = (val_scores_if < th).astype(int)
    f1 = f1_score(y_val_if, preds, zero_division=0)
    if f1 > best_f1:
        best_f1 = f1
        best_th = th

print("Best IF threshold:", best_th)
print("Best IF validation F1:", best_f1)


#isolation forest val + test
def eval_if(scores, y_true, threshold):
    preds = (scores < threshold).astype(int)
    return {
        "Precision": precision_score(y_true, preds, zero_division=0),
        "Recall": recall_score(y_true, preds, zero_division=0),
        "F1": f1_score(y_true, preds, zero_division=0),
        "ROC-AUC": roc_auc_score(y_true, -scores)  # invert for consistency
    }

metrics_val_if = eval_if(val_scores_if, y_val_if, best_th)
metrics_test_if = eval_if(test_scores_if, y_test_if, best_th)

print("IF Validation:", metrics_val_if)
print("IF Test:", metrics_test_if)
# Out:
# Best IF threshold: 0.008067007890468991
# Best IF validation F1: 0.0819833087874325
# IF Validation: {'Precision': 0.0427547363031234, 'Recall': 0.9940476190476191, 'F1': 0.0819833087874325, 'ROC-AUC': np.float64(0.28245022420431837)}
# IF Test: {'Precision': 0.06575342465753424, 'Recall': 1.0, 'F1': 0.12339331619537275, 'ROC-AUC': np.float64(0.467460669255882)}
